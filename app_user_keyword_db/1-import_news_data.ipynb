# %%
import os
import sys
import pandas as pd
import argparse
from datetime import datetime
import pathlib

# # Setup Django environment
# # Alternative 1: Use absolute path construction
# current_dir = os.path.abspath('')
# parent_dir = os.path.dirname(current_dir)
# sys.path.insert(0, parent_dir)

# # Alternative 2: Use pathlib for more modern path handling
# parent_path = pathlib.Path().absolute().parent
# sys.path.insert(0, str(parent_path))

# 新增：將上一層目錄加入 sys.path
parent_path = pathlib.Path().absolute().parent
sys.path.insert(0, str(parent_path))

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'website_configs.settings')
import django
django.setup()
# 重要：設定環境變數以允許在 Jupyter 的異步環境中執行同步操作
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Now we can import Django models
from app_user_keyword_db.models import NewsData

# %%
# Read CSV file
csv_file_path = '../app_user_keyword/dataset/sentiment_20250428.csv'
# csv_file_path = '../app_user_keyword/dataset/cna_news_preprocessed_12weeks.csv'
df = pd.read_csv(csv_file_path, sep='|')

# Process each row and create a NewsData object
for idx, row in df.iterrows():
    try:
        # Convert date string to datetime object
        date_obj = datetime.strptime(row['date'], '%Y-%m-%d').date()

        # Create or update NewsData object
        news_data, created = NewsData.objects.update_or_create(
            item_id=row['item_id'],
            defaults={
                'date': date_obj,
                'category': row['category'],
                'title': row['title'],
                'content': row['content'],
                'sentiment': row['sentiment'],
                #'summary': row['summary'],
                'top_key_freq': row['top_key_freq'],
                'tokens': row['tokens'],
                'tokens_v2': row['tokens_v2'],
                'entities': row['entities'],
                'token_pos': row['token_pos'],
                'link': row['link'],
                'photo_link': row['photo_link'] if row['photo_link'] != "" and not pd.isna(row['photo_link']) else None,
            }
        )
        if created:
            print(f"Created new NewsData object with item_id: {row['item_id']}")
        else:
            print(f"Updated existing NewsData object with item_id: {row['item_id']}")
    except Exception as e:
        print(f"Error at row {idx}: {e}")
        print(row)
# photo_link 欄位的值可能為以下幾種情況：
# 實際有值的 URL 字串
# 空字串 ("")
# Pandas NaN 值（當 CSV 檔案中該欄位為空時）
# None 值
# Out:
# Created new NewsData object with item_id: org_unknown_1
# Created new NewsData object with item_id: org_unknown_2
# Created new NewsData object with item_id: org_unknown_3
# Created new NewsData object with item_id: org_unknown_4
# Created new NewsData object with item_id: org_unknown_5
# Created new NewsData object with item_id: org_unknown_6
# Created new NewsData object with item_id: org_unknown_7
# Created new NewsData object with item_id: org_unknown_8
# Created new NewsData object with item_id: org_unknown_9
# Created new NewsData object with item_id: eco_unknown_10
# Created new NewsData object with item_id: eco_unknown_11
# Created new NewsData object with item_id: eco_unknown_12
# Created new NewsData object with item_id: eco_unknown_13
# Created new NewsData object with item_id: eco_unknown_14
# Created new NewsData object with item_id: eco_unknown_15
# Created new NewsData object with item_id: eco_unknown_16
# Created new NewsData object with item_id: eco_unknown_17
# Created new NewsData object with item_id: eco_unknown_18
# Created new NewsData object with item_id: glo_unknown_19
# Created new NewsData object with item_id: glo_unknown_20
# Created new NewsData object with item_id: glo_unknown_21
# Created new NewsData object with item_id: glo_unknown_22
# Created new NewsData object with item_id: glo_unknown_23
# Created new NewsData object with item_id: glo_unknown_24
# Created new NewsData object with item_id: glo_unknown_25
# Created new NewsData object with item_id: glo_unknown_26
# Created new NewsData object with item_id: glo_unknown_27
# Updated existing NewsData object with item_id: org_unknown_1
# Updated existing NewsData object with item_id: org_unknown_2
# Updated existing NewsData object with item_id: org_unknown_3
# Updated existing NewsData object with item_id: org_unknown_4
# Updated existing NewsData object with item_id: org_unknown_5
# Updated existing NewsData object with item_id: org_unknown_6
# Updated existing NewsData object with item_id: org_unknown_7
# Updated existing NewsData object with item_id: org_unknown_8
# Updated existing NewsData object with item_id: org_unknown_9
# Updated existing NewsData object with item_id: eco_unknown_10
# Updated existing NewsData object with item_id: eco_unknown_11
# Updated existing NewsData object with item_id: eco_unknown_12
# Updated existing NewsData object with item_id: eco_unknown_13
# Updated existing NewsData object with item_id: eco_unknown_14
# Updated existing NewsData object with item_id: eco_unknown_15
# Updated existing NewsData object with item_id: eco_unknown_16
# Updated existing NewsData object with item_id: eco_unknown_17
# Updated existing NewsData object with item_id: eco_unknown_18
# Updated existing NewsData object with item_id: glo_unknown_19
# Updated existing NewsData object with item_id: glo_unknown_20
# Updated existing NewsData object with item_id: glo_unknown_21
# Updated existing NewsData object with item_id: glo_unknown_22
# Updated existing NewsData object with item_id: glo_unknown_23
# Updated existing NewsData object with item_id: glo_unknown_24
# Updated existing NewsData object with item_id: glo_unknown_25
# Updated existing NewsData object with item_id: glo_unknown_26
# Updated existing NewsData object with item_id: glo_unknown_27
# Created new NewsData object with item_id: org_20250425_1
# Created new NewsData object with item_id: org_20250425_2
# Created new NewsData object with item_id: org_20250425_3
# Created new NewsData object with item_id: org_20250425_4
# Created new NewsData object with item_id: org_20250425_5
# Created new NewsData object with item_id: org_20250424_6
# Created new NewsData object with item_id: org_20250424_7
# Created new NewsData object with item_id: org_20250424_8
# Created new NewsData object with item_id: org_20250424_9
# Created new NewsData object with item_id: eco_20250425_10
# Created new NewsData object with item_id: eco_20250424_11
# Created new NewsData object with item_id: eco_20250424_12
# Created new NewsData object with item_id: eco_20250423_13
# Created new NewsData object with item_id: eco_20250423_14
# Created new NewsData object with item_id: eco_20250420_15
# Created new NewsData object with item_id: eco_20250420_16
# Created new NewsData object with item_id: eco_20250417_17
# Created new NewsData object with item_id: eco_20250416_18
# Created new NewsData object with item_id: glo_20250425_19
# Created new NewsData object with item_id: glo_20250425_20
# Created new NewsData object with item_id: glo_20250425_21
# Created new NewsData object with item_id: glo_20250425_22
# Created new NewsData object with item_id: glo_20250425_23
# Created new NewsData object with item_id: glo_20250425_24
# Created new NewsData object with item_id: glo_20250425_25
# Created new NewsData object with item_id: glo_20250425_26
# Created new NewsData object with item_id: glo_20250425_27
# Created new NewsData object with item_id: org_20250428_1
# Created new NewsData object with item_id: org_20250427_2
# Created new NewsData object with item_id: org_20250427_3
# Created new NewsData object with item_id: org_20250427_4
# Created new NewsData object with item_id: org_20250426_5
# Created new NewsData object with item_id: org_20250426_6
# Created new NewsData object with item_id: org_20250425_7
# Created new NewsData object with item_id: glo_20250428_19
# Created new NewsData object with item_id: glo_20250428_20
# Created new NewsData object with item_id: glo_20250427_21
# Created new NewsData object with item_id: glo_20250427_22
# Created new NewsData object with item_id: glo_20250427_23
# Created new NewsData object with item_id: glo_20250427_24
# Created new NewsData object with item_id: glo_20250427_25
# Created new NewsData object with item_id: glo_20250426_26
# Created new NewsData object with item_id: glo_20250426_27

# %%
created
# Out:
# True
